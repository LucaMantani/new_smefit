# %%
from webdav3.client import Client

# admin login details to a test server
options = {
 'webdav_hostname': "https://surfdrive.surf.nl/public.php/webdav/",
 'webdav_login':    "widktYypyLy9b8K",
 'webdav_password': "Cgt6fePMgK"
}

test_server = Client(options)


test_server.upload_sync(remote_path="report_260427_jth_fig_app_e_04.pdf", local_path="report_260427_jth_fig_app_e_04.pdf")

# %%
files = test_server.list(".")
print(files)
# Out:
# ['webdav/', 'report_260427_jth_fig_app_e_04.pdf']

# %%
test_server.download_sync(
    remote_path="report_260427_jth_fig_app_e_04.pdf",
    local_path="report_260427_jth_fig_app_e_04.pdf",
)

# %%
test_server.clean("report_260427_jth_fig_app_e_04.pdf")

# %%
# test_server.move(remote_path_from="report_260427_jth_fig_app_e_04", remote_path_to="new_folder/report_260427_jth_fig_app_e_04/")
# Out:
# ---------------------------------------------------------------------------
# RemoteResourceNotFound                    Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 test_server.move(remote_path_from="report_260427_jth_fig_app_e_04", remote_path_to="new_folder/report_260427_jth_fig_app_e_04/")
#
# File ~/miniconda3/envs/new_smefit/lib/python3.14/site-packages/webdav3/client.py:78, in wrap_connection_error.<locals>._wrapper(self, *args, **kw)
#      76 log.debug("Requesting %s(%s, %s)", fn, args, kw)
#      77 try:
# ---> 78     res = fn(self, *args, **kw)
#      79 except requests.ConnectionError:
#      80     raise NoConnection(self.webdav.hostname)
#
# File ~/miniconda3/envs/new_smefit/lib/python3.14/site-packages/webdav3/client.py:853, in Client.move(self, remote_path_from, remote_path_to, overwrite)
#     851 urn_from = Urn(remote_path_from)
#     852 if not self.check(urn_from.path()):
# --> 853     raise RemoteResourceNotFound(urn_from.path())
# ...
